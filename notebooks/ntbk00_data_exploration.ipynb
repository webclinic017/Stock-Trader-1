# %%
import os, sys
sys.path.append('../src/')
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import data.dataset as dtst
import features.preprocessing as prep
import visualization.visualize as vis
# Out:
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
n_assets = 10

# Loading the raw stock files
stocks_folderpath = '../../../Datasets/Stock Market Dataset/stocks/'
df_stocks = dtst.load_rawdata(stocks_folderpath, n_files=n_assets)

print("Number of assets:", len(df_stocks))
df_stocks.keys()
# Out:
# Number of assets: 10
# dict_keys(['A', 'AA', 'AACG', 'AAL', 'AAMC', 'AAME', 'AAN', 'AAOI', 'AAON', 'AAP'])

# %%
# Loading the raw stock files
etfs_folderpath = '../../../Datasets/Stock Market Dataset/etfs/'
df_etfs = dtst.load_rawdata(etfs_folderpath, n_files=n_assets)

print("Number of assets:", len(df_etfs))
df_etfs.keys()
# Out:
# Number of assets: 10
# dict_keys(['AAAU', 'AADR', 'AAXJ', 'ABEQ', 'ACES', 'ACIO', 'ACSG', 'ACSI', 'ACT', 'ACWF'])

# %%
vis.plot_assets_timeline(df_stocks, subplotsize=(10, 2))

# %%
vis.plot_assets_timeline(df_etfs, subplotsize=(10, 2))
