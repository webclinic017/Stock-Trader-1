# %%
import os, sys
import copy
from collections import Counter
from datetime import datetime

sys.path.append('../src/')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import data.dataset as dtst
import features.preprocessing as prep
import visualization.visualize as vis
import models.evaluate_model as evl
from stocks.analytics import StockView

import warnings
warnings.filterwarnings('ignore')

np.random.seed(43)
# Out:
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Main variables:
tickerspath = '../data/processed/test/'
ticker = np.random.choice(os.listdir(tickerspath)).split('.')[0]
current_date = datetime(2018, 1, 1)

print(f"{ticker} at chosen date:", current_date)
# Out:
# SLP at chosen date: 2018-01-01 00:00:00

# %% [markdown]
# # Running analysis on a specific date:

# %%
df = dtst.load_stock_ticker(ticker)
stv = StockView(df, ticker=ticker)
stv.run_daily_view(current_date)
# Out:
# SLP stock analysis at 2018-01-02
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: False
# MACD: 0.04445
# Signal: 0.093287
# Histogram: -0.048838
# Williams %: -96.551774
# Trend prediction: Down

# %% [markdown]
# # Running analysis on random dates:

# %%
stv.run_random_dates(10)
# Out:
# SLP stock analysis at 2009-03-10
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: False
# MACD: -0.023528
# Signal: -0.021474
# Histogram: -0.002054
# Williams %: -38.461535
# Trend prediction: Up
# SLP stock analysis at 2009-04-09
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: False
# MACD: 0.003415
# Signal: -0.002885
# Histogram: 0.0063
# Williams %: -66.666653
# Trend prediction: Down
# SLP stock analysis at 2008-03-28
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: False
# MACD: -0.24353
# Signal: -0.28763
# Histogram: 0.044099
# Williams %: -56.756752
# Trend prediction: Standing
# SLP stock analysis at 2001-03-22
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: True
# MACD: -0.012878
# Signal: -0.003987
# Histogram: -0.008891
# Williams %: -100.0
# Trend prediction: Down
# SLP stock analysis at 2002-08-23
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: False
# MACD: 0.007713
# Signal: 0.004407
# Histogram: 0.003306
# Williams %: -0.0
# Trend prediction: Standing
# SLP stock analysis at 2015-08-26
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 0.004728
# Signal: 0.011962
# Histogram: -0.007234
# Williams %: -28.571484
# Trend prediction: Standing
# SLP stock analysis at 2003-07-11
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 0.000521
# Signal: 0.004016
# Histogram: -0.003496
# Williams %: -55.55555
# Trend prediction: Down
# SLP stock analysis at 2017-07-31
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 0.71758
# Signal: 0.703825
# Histogram: 0.013755
# Williams %: -48.561135
# Trend prediction: Down
# SLP stock analysis at 2019-07-02
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 1.04687
# Signal: 1.035846
# Histogram: 0.011024
# Williams %: -25.956254
# Trend prediction: Up
# SLP stock analysis at 2015-10-16
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 0.384795
# Signal: 0.498689
# Histogram: -0.113894
# Williams %: -66.265051
# Trend prediction: Down
