# %%
import os, sys
import copy
from collections import Counter
from datetime import datetime

sys.path.append('../src/')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import data.dataset as dtst
import features.preprocessing as prep
import visualization.visualize as vis
import models.evaluate_model as evl
from stocks.analytics import StockView

import warnings
warnings.filterwarnings('ignore')

np.random.seed(42)
# Out:
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Main variables:
tickerspath = '../data/processed/test/'
ticker = np.random.choice(os.listdir(tickerspath)).split('.')[0]
current_date = datetime(2018, 1, 1)

print(f"{ticker} at chosen date:", current_date)
# Out:
# OPY at chosen date: 2018-01-01 00:00:00

# %% [markdown]
# # Running analysis on a specific date:

# %%
df = dtst.load_stock_ticker(ticker)
stv = StockView(df, ticker=ticker)
stv.run_daily_view(current_date)
# Out:
# OPY stock analysis at 2018-01-02
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 0.411649
# Signal: 0.789984
# Histogram: -0.378335
# Williams %: -100.0
# Trend prediction: Down

# %% [markdown]
# # Running analysis on random dates:

# %%
stv.run_random_dates(10)
# Out:
# OPY stock analysis at 2003-06-09
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 1.07521
# Signal: 1.11168
# Histogram: -0.03647
# Williams %: -36.666679
# Trend prediction: Standing
# OPY stock analysis at 2014-12-31
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: False
# MACD: 0.069473
# Signal: -0.016521
# Histogram: 0.085994
# Williams %: -23.86361
# Trend prediction: Standing
# OPY stock analysis at 2012-04-18
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: True
# MACD: -0.101016
# Signal: -0.043067
# Histogram: -0.057949
# Williams %: -74.493954
# Trend prediction: Down
# OPY stock analysis at 2001-11-12
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: False
# MACD: -0.059795
# Signal: -0.197789
# Histogram: 0.137994
# Williams %: -0.0
# Trend prediction: Up
# OPY stock analysis at 2017-08-07
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: True
# MACD: -0.076569
# Signal: -0.061175
# Histogram: -0.015394
# Williams %: -44.44446
# Trend prediction: Up
# OPY stock analysis at 2013-09-12
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: False
# MACD: -0.502948
# Signal: -0.474008
# Histogram: -0.02894
# Williams %: -85.492195
# Trend prediction: Standing
# OPY stock analysis at 2012-08-09
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: False
# MACD: -0.330222
# Signal: -0.280163
# Histogram: -0.050059
# Williams %: -58.273397
# Trend prediction: Up
# OPY stock analysis at 2011-08-10
# 9 days S.M.A > 21 days S.M.A: False
# 9 days S.M.A > 50 days S.M.A: False
# 21 days S.M.A > 50 days S.M.A: False
# MACD: -1.846089
# Signal: -0.939798
# Histogram: -0.906291
# Williams %: -95.979904
# Trend prediction: Down
# OPY stock analysis at 2000-07-10
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 0.325364
# Signal: 0.267334
# Histogram: 0.05803
# Williams %: -17.857143
# Trend prediction: Standing
# OPY stock analysis at 2006-09-15
# 9 days S.M.A > 21 days S.M.A: True
# 9 days S.M.A > 50 days S.M.A: True
# 21 days S.M.A > 50 days S.M.A: True
# MACD: 0.585679
# Signal: 0.643435
# Histogram: -0.057756
# Williams %: -17.301042
# Trend prediction: Up
