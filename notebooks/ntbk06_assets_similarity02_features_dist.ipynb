# %%
import os, sys
import copy
from collections import Counter
from datetime import datetime, timedelta

sys.path.append('../src/')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import pairwise_distances
from dtaidistance import dtw

import data.dataset as dtst
import features.preprocessing as prep
import visualization.visualize as vis
import models.evaluate_model as evl
from stocks.analytics import StockView, StockSim

import warnings
warnings.filterwarnings('ignore')

np.random.seed(43)
# Out:
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# c:\users\weldl\miniconda3\envs\i2a2-fm\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Main variables:
tickerspath = '../data/interim/stocks/'

filename = np.random.choice(os.listdir(tickerspath))
ticker = filename.split('.')[0]
current_date = datetime(2019, 1, 1)

print(f"{ticker} at chosen date:", current_date)
# Out:
# MIY at chosen date: 2019-01-01 00:00:00

# %%
st_sim = StockSim(ticker, current_date, days_interval=30, n_assets=3)
# Out:
# 5883 other assets available.

# %%
st_sim.run(method='features_dist')
